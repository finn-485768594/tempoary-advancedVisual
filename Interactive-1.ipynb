# %% [markdown]
# Connected to base (Python 3.11.5)

# %%
# first things first lets get the data we ned for the tasl
import cv2
from pathlib import Path

data_dir = Path("data_provided_for_task/IconDataset/png")
for p in data_dir.rglob("*.png"):
    img = cv2.imread(str(p), cv2.IMREAD_UNCHANGED)  # BGRA if has alpha
    # process as numpy array
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File finn-485768594\tempoary-advancedVisual\C2_project.py:2
#       1 # first things first lets get the data we ned for the tasl
# ----> 2 import cv2
#       3 from pathlib import Path
#       5 data_dir = Path("data_provided_for_task/IconDataset/png")
#
# ModuleNotFoundError: No module named 'cv2'
